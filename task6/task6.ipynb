# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix

import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# !pip install -r requirements.txt

# !bash ./datasets/download_cyclegan_dataset.sh monet2photo

# !bash ./scripts/download_cyclegan_model.sh style_monet

os.makedirs('/content/pytorch-CycleGAN-and-pix2pix/datasets/monet2photo/testC', exist_ok=True)

# %%
#теперь картинку положи в папку /content/pytorch-CycleGAN-and-pix2pix/datasets/monet2photo/testC

# !python test.py --dataroot '/content/pytorch-CycleGAN-and-pix2pix/datasets/monet2photo/testC' --name style_monet_pretrained --model test  --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: /content/pytorch-CycleGAN-and-pix2pix/datasets/monet2photo/testC	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: style_monet_pretrained        	[default: experiment_name]
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# название файла поменять
img = cv2.imread('/content/pytorch-CycleGAN-and-pix2pix/results/style_monet_pretrained/test_latest/images/ru_fake.png')
plt.imshow(img)
print(np.mean(img))

# # название файла поменять
# img = plt.imread('/content/pytorch-CycleGAN-and-pix2pix/results/style_monet_pretrained/test_latest/images/bridge-3729954_1280_real.png')
# plt.imshow(img)
# Out:
# 125.90627034505208
